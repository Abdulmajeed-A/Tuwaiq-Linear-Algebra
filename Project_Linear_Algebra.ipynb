# %% [markdown]
# # Step 1: Import Libraries

# %% [markdown]
# # Step 2: Create or Load Data

# %% [markdown]
# # Step 3: Center the Data

# %% [markdown]
# # Step 4: Compute Covariance Matrix

# %% [markdown]
# # Step 5: Compute Eigenvalues & Eigenvectors

# %% [markdown]
# # Step 6: Sort and Select Principal Components

# %% [markdown]
# # Step 7: Transform Data

# %% [markdown]
# # Step 8: Visualize
